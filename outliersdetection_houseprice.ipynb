# %%
   OUTLIER DETECTION

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df= pd.read_csv("C:\\Users\\aishu\\jupyter class\\house_price.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   location        13200 non-null  object
#  1   size            13200 non-null  object
#  2   total_sqft      13200 non-null  float64
#  3   bath            13200 non-null  float64
#  4   price           13200 non-null  float64
#  5   bhk             13200 non-null  int64
#  6   price_per_sqft  13200 non-null  int64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 722.0+ KB

# %%
df.describe(include="all")
# Out:
#        location   size    total_sqft          bath         price  \
# count     13200  13200  13200.000000  13200.000000  13200.000000
# unique      241     31           NaN           NaN           NaN
# top       other  2 BHK           NaN           NaN           NaN
# freq       2872   5192           NaN           NaN           NaN
# mean        NaN    NaN   1555.302783      2.691136    112.276178
# std         NaN    NaN   1237.323445      1.338915    149.175995
# min         NaN    NaN      1.000000      1.000000      8.000000
# 25%         NaN    NaN   1100.000000      2.000000     50.000000
# 50%         NaN    NaN   1275.000000      2.000000     71.850000
# 75%         NaN    NaN   1672.000000      3.000000    120.000000
# max         NaN    NaN  52272.000000     40.000000   3600.000000
#
#                  bhk  price_per_sqft
# count   13200.000000    1.320000e+04
# unique           NaN             NaN
# top              NaN             NaN
# ...

# %%
df.notnull
# Out:
# <bound method DataFrame.notnull of                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
# 13199              Doddathoguru      1 BHK       550.0   1.0   17.00    1
#
#        price_per_sqft
# 0                3699
# ...

# %%
df.duplicated().sum()
# Out:
# 1049

# %%
HERE DUPLICATE ROWS.SO WE NEED TO REMOVE IT

# %%
#remove duplicate rows
df.drop_duplicates(inplace=True)
df.to_csv('modified_house_price.csv',index=False)
df_modified=pd.read_csv('modified_house_price.csv')
df_modified
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 12146         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 12147                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 12148                     other      4 BHK      3600.0   5.0  400.00    4
# 12149     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 12150           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.isnull().sum()
# Out:
# location          0
# size              0
# total_sqft        0
# bath              0
# price             0
# bhk               0
# price_per_sqft    0
# dtype: int64

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# ...

# %%
df.notnull
# Out:
# <bound method DataFrame.notnull of                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# ...

# %%
df.shape
# Out:
# (12151, 7)

# %%
OUTLIER DETECTION AND REMOVAL STRATERGIES

# %%
MEAN

# %%
df.price_per_sqft.min()
# Out:
# 267

# %%
df.price_per_sqft.max()
# Out:
# 12000000

# %%
df.price_per_sqft.mean()
# Out:
# 8132.641840177763

# %%
df.price_per_sqft.median()
# Out:
# 5500.0

# %%
The disparity between mean and median suggests outlier presence,
as mean is sensitive and median robust to extreme values.

# %%
sns.distplot(df['price_per_sqft'],color='g')
plt.title('Distribution of price per sqft with Outliers',color='g')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\2779792715.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'],color='g')
# Text(0.5, 1.0, 'Distribution of price per sqft with Outliers')

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
Quantile() to find out the percentiles.

# %%
df.price_per_sqft.quantile([0.05,0.1,0.25,0.5,0.75,0.90,0.92,0.94,0.96,0.98,0.99])
# Out:
# 0.05     3150.0
# 0.10     3513.0
# 0.25     4312.0
# 0.50     5500.0
# 0.75     7461.0
# 0.90    11904.0
# 0.92    13129.0
# 0.94    14695.0
# 0.96    16666.0
# 0.98    20000.0
# 0.99    24000.0
# Name: price_per_sqft, dtype: float64

# %%
There is an significant variation between 98th and 99th percentile, 
indicating presence of outliers.

# %%
df[df.price_per_sqft>df.price_per_sqft.quantile(0.95)] #outliers
# Out:
#            location       size  total_sqft  bath   price  bhk  price_per_sqft
# 7      Rajaji Nagar      4 BHK      3300.0   4.0   600.0    4           18181
# 9             other  6 Bedroom      1020.0   6.0   370.0    6           36274
# 45       HSR Layout  8 Bedroom       600.0   9.0   200.0    8           33333
# 48         KR Puram  2 Bedroom       800.0   1.0   130.0    2           16250
# 69            other  3 Bedroom       500.0   3.0   100.0    3           20000
# ...             ...        ...         ...   ...     ...  ...             ...
# 13081         other  6 Bedroom      8000.0   6.0  2800.0    6           35000
# 13097         other      1 BHK       250.0   2.0    40.0    1           16000
# 13141         other  3 Bedroom      2000.0   2.0   360.0    3           18000
# 13142         other      2 BHK      1140.0   1.0   185.0    2           16228
# 13185      Hulimavu      1 BHK       500.0   1.0   220.0    1           44000
#
# [607 rows x 7 columns]

# %%
#Data without outliers
df1=df[df.price_per_sqft<df.price_per_sqft.quantile(0.95)]
df1
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
sns.distplot(df1['price_per_sqft'],color='g')
plt.title('Distribution of Price per Sqft without outliers',color='g')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\2053997931.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df1['price_per_sqft'],color='g')
# Text(0.5, 1.0, 'Distribution of Price per Sqft without outliers')

# %%
sns.boxplot(df1['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
print("Before removing outliers:",len(df))
print("After removing outliers:",len(df1))
print("Outliers:",len(df)-len(df1))
# Out:
# Before removing outliers: 12151
# After removing outliers: 11542
# Outliers: 609

# %%
Following outlier removal via the mean method, the distribution plot now 
demonstrates a bell-shaped curve, indicative of a more normal distribution. Notably, 
660 outliers have been effectively eliminated from the dataset, 
contributing to a more accurate representation of the underlying data distribution.

# %%
.PERCENTILE METHOD

# %%
upper_limit=df['price_per_sqft'].quantile(0.95)
lower_limit=df['price_per_sqft'].quantile(0.05)

# %%
print("Upper Limit:",upper_limit)
print("Lower Limit:",lower_limit)
# Out:
# Upper Limit: 15600.0
# Lower Limit: 3150.0

# %%
sns.distplot(df['price_per_sqft'],color='r')
plt.title('Distribution of Price Per Sqft with Outliers',color='r')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\3819253537.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'],color='r')
# Text(0.5, 1.0, 'Distribution of Price Per Sqft with Outliers')

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
#finding outliers
df.loc[(df['price_per_sqft']>upper_limit) | (df['price_per_sqft']<lower_limit)]
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 7                  Rajaji Nagar      4 BHK      3300.0   4.0  600.00    4
# 9                         other  6 Bedroom      1020.0   6.0  370.00    6
# 20                      Kengeri      1 BHK       600.0   1.0   15.00    1
# 41               Sarjapur  Road      3 BHK      1254.0   3.0   38.00    3
# 45                   HSR Layout  8 Bedroom       600.0   9.0  200.00    8
# ...                         ...        ...         ...   ...     ...  ...
# 13121  Electronic City Phase II      3 BHK      1651.0   3.0   49.53    3
# 13141                     other  3 Bedroom      2000.0   2.0  360.00    3
# 13142                     other      2 BHK      1140.0   1.0  185.00    2
# 13155                 Kothannur  4 Bedroom      1600.0   4.0   45.00    4
# 13185                  Hulimavu      1 BHK       500.0   1.0  220.00    1
#
#        price_per_sqft
# 7               18181
# 9               36274
# ...

# %%
#deleting the outliers
df2=df.loc[(df['price_per_sqft']<=upper_limit) & (df['price_per_sqft']>=lower_limit)]
df2
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
print("Before removing outliers:",len(df))
print("After removing outliers:",len(df2))
print("Outliers:",len(df)-len(df2))
# Out:
# Before removing outliers: 12151
# After removing outliers: 10940
# Outliers: 1211

# %%
sns.distplot(df2['price_per_sqft'],color='g')
plt.title('Distribution of Price Per Sqft without outliers',color='g')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\1263576762.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df2['price_per_sqft'],color='g')
# Text(0.5, 1.0, 'Distribution of Price Per Sqft without outliers')

# %%
sns.boxplot(df2['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
Upon implementing the percentile technique for outlier removal,
our distribution plot exhibited a near bell-shaped curve,
suggesting a more normal distribution. Remarkably, 660 outliers were successfully 
eliminated from the dataset, enhancing its accuracy and aligning it more closely with the
underlying data distribution

# %%
#CAPPING -cahne the outliers to upper or lower values
new_df2=df.copy()
new_df2.loc[(new_df2['price_per_sqft']>upper_limit),'price_per_sqft']=upper_limit
new_df2.loc[(new_df2['price_per_sqft']<lower_limit),'price_per_sqft']=lower_limit

# %%
sns.boxplot(new_df2['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
3.IQR METHOD

# %%
sns.distplot(df['price_per_sqft'])
plt.title('Distribution of price Per Sqft with outliers',color='b')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\373823651.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# Text(0.5, 1.0, 'Distribution of price Per Sqft with outliers')

# %%
sns.boxplot(df['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
Q1=df.price_per_sqft.quantile(0.25)
Q3=df.price_per_sqft.quantile(0.75)
IQR=Q3-Q1
print("Q1=",Q1)
print("Q3=",Q3)
print("IQR=",IQR)
# Out:
# Q1= 4312.0
# Q3= 7461.0
# IQR= 3149.0

# %%
lower_whisker=Q1-1.5*IQR
upper_whisker=Q3+1.5*IQR
print('Lower Whisker=',lower_whisker)
print('Upper Whisker=',upper_whisker)
# Out:
# Lower Whisker= -411.5
# Upper Whisker= 12184.5

# %%
#finding otuliers
df[(df.price_per_sqft<-308.0) | (df.price_per_sqft>12184.5)]
# Out:
#            location       size  total_sqft  bath  price  bhk  price_per_sqft
# 7      Rajaji Nagar      4 BHK      3300.0   4.0  600.0    4           18181
# 9             other  6 Bedroom      1020.0   6.0  370.0    6           36274
# 22      Thanisandra  4 Bedroom      2800.0   5.0  380.0    4           13571
# 45       HSR Layout  8 Bedroom       600.0   9.0  200.0    8           33333
# 48         KR Puram  2 Bedroom       800.0   1.0  130.0    2           16250
# ...             ...        ...         ...   ...    ...  ...             ...
# 13114         other      3 BHK      1903.0   2.0  293.0    3           15396
# 13141         other  3 Bedroom      2000.0   2.0  360.0    3           18000
# 13142         other      2 BHK      1140.0   1.0  185.0    2           16228
# 13157         other  7 Bedroom      1400.0   7.0  218.0    7           15571
# 13185      Hulimavu      1 BHK       500.0   1.0  220.0    1           44000
#
# [1142 rows x 7 columns]

# %%
#df without outliers
df3=df[(df.price_per_sqft>-308.0) & (df.price_per_sqft<12184.5)]
df3
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
print('Before removing outliers:',len(df))
print('After removing outliers',len(df3))
print('Outliers:',len(df)-len(df3))
# Out:
# Before removing outliers: 12151
# After removing outliers 11009
# Outliers: 1142

# %%
sns.distplot(df3['price_per_sqft'],color='y')
plt.title('Distribution of Price Per Sqft without outliers')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\1727763733.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df3['price_per_sqft'],color='y')
# Text(0.5, 1.0, 'Distribution of Price Per Sqft without outliers')

# %%
sns.boxplot(df3['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
By employing the IQR method for outlier removal, our distribution plot exhibited a bell-shaped curve,
indicating a more normal distribution. Impressively,
we eliminated a total of 1142 outliers from the dataset, 
significantly improving its accuracy and alignment with the underlying data distribution.

# %%
4.NORMAL DISTRIBUTION

# %%
df.price_per_sqft.describe()
# Out:
# count    1.215100e+04
# mean     8.132642e+03
# std      1.112329e+05
# min      2.670000e+02
# 25%      4.312000e+03
# 50%      5.500000e+03
# 75%      7.461000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
m=df.price_per_sqft.mean()
m
# Out:
# 8132.641840177763

# %%
s=df.price_per_sqft.std()
s
# Out:
# 111232.90089570847

# %%
#-3sigma
m-3*s
# Out:
# -325566.06084694766

# %%
#+3sigma
m+3*s
# Out:
# 341831.3445273032

# %%
#finding outliers
df[(df.price_per_sqft<-312261.14424190175) | (df.price_per_sqft>328101.8177267502)]
# Out:
#              location       size  total_sqft  bath  price  bhk  price_per_sqft
# 345             other  3 Bedroom        11.0   3.0   74.0    3          672727
# 1106            other  5 Bedroom        24.0   2.0  150.0    5          625000
# 4044   Sarjapur  Road  4 Bedroom         1.0   4.0  120.0    4        12000000
# 4924            other      7 BHK         5.0   7.0  115.0    7         2300000
# 11447      Whitefield  4 Bedroom        60.0   4.0  218.0    4          363333

# %%
#data without outliers
df4=df[(df.price_per_sqft>-312261.14424190175) & (df.price_per_sqft<328101.8177267502)]
df4
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
print("Before removing outliers:",len(df))
print("After removing outliers:",len(df4))
print("Outliers:",len(df)-len(df4))
# Out:
# Before removing outliers: 12151
# After removing outliers: 12146
# Outliers: 5

# %%
sns.distplot(df4['price_per_sqft'],color='m')
# Out:
# C:\Users\aishu\AppData\Local\Temp\ipykernel_7316\4222713904.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df4['price_per_sqft'],color='m')
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(df4['price_per_sqft'])
# Out:
# <Axes: ylabel='price_per_sqft'>

# %%
Utilizing the Normal Distribution Method, the dataset initially 
contained 12151 rows. Upon outlier removal, 12146 rows remained, 
identifying 5 outliers. This method facilitated data refinement,
resulting in a more accurate representation with minimal impact on the dataset's overall size.

# %%
5.ZSCORE METHOD

# %%
mean=df.price_per_sqft.mean()
mean
# Out:
# 8132.641840177763

# %%
s=df.price_per_sqft.std()
s
# Out:
# 111232.90089570847

# %%
lower_limit=m-3*s
lower_limit
# Out:
# -325566.06084694766

# %%
upper_limit=m+3*s
upper_limit
# Out:
# 341831.3445273032

# %%
#data without outliers
df5=df[(df.price_per_sqft>lower_limit) & (df.price_per_sqft<upper_limit)]
df5
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0   2.0   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0   5.0  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0   2.0   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0   3.0   95.00    3
# 4                      Kothanur      2 BHK      1200.0   2.0   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13194         Green Glen Layout      3 BHK      1715.0   3.0  112.00    3
# 13195                Whitefield  5 Bedroom      3453.0   4.0  231.00    5
# 13196                     other      4 BHK      3600.0   5.0  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0   2.0   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0   4.0  488.00    4
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
#finding the numerical columns
#checking the dataset and selecting the numerical columns
num_col=df.select_dtypes(include=['int', 'float']).columns
num_col
# Out:
# Index(['total_sqft', 'bath', 'price', 'bhk', 'price_per_sqft'], dtype='object')

# %%
#compute correlation mathrix
corre_matrix=df[num_col].corr()

# %%
#plotting heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corre_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()

# %%
#plot scatterplot
sns.pairplot(df)
plt.show()

# %%
*Total Sqft and Price Per Sqft exhibit a very weak negative correlation (-0.01),
suggesting almost no linear relationship between them.

# %%
*Total Sqft correlates moderately positively with BHK (0.35), Price (0.57), and Bath (0.39),
suggesting that as square footage increases, so do bedrooms,
property price, and bathrooms, albeit not perfectly linearly.

# %%
Bath shows a strong positive correlation (0.90) with BHK, 
indicating a robust linear relationship between the number of bathrooms and bedrooms. It also correlates moderately positively with Price (0.46)
and Total Sqft (0.39), 
suggesting properties with more bathrooms command higher prices and have larger square footage.

# %%
*Price also exhibits moderate positive
correlations with bhk "0.39" and total_sqft "0.57", indicating that both the number of bedrooms and the total square 
footage have a positive impact on property prices, though again,
not in a perfectly linear manner.

# %%
Overall, these correlation coefficients provide
valuable insights into how different factors are 
interrelated within our dataset, aiding in better understanding and potentially predicting
property prices based on their characteristics
